# %% [markdown]
# # Jupyter notebooks para desarrollo y presentación

# %%
# Celda 1: Importar librerías
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Configuración general
sns.set(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# # clima_contaminacion

# %%
# Celda 2: Cargar los datos
DATA_DIR = os.path.join("..", "data", "processed")  # Ajusta según tu ruta
archivo_clima_cont = "clima_contaminacion.csv"

df = pd.read_csv(os.path.join(DATA_DIR, archivo_clima_cont))
df.head()
# Out:
#    Anio  Mes    TempMax    TempMin  Precipitacion       pm10      pm2_5  \
# 0  2020    1  25.103226  16.816129       1.374194  14.172637  12.203810
# 1  2020    2  26.451724  16.293103       0.227586  15.015327  13.090243
# 2  2020    3  27.358065  16.029032       0.251613  14.320850  12.337422
# 3  2020    4  27.700000  17.243333       3.066667  14.675192  12.627095
# 4  2020    5  25.916129  18.029032      10.641935  14.182802  12.829312
#
#            CO        NO2         O3
# 0  583.596093  14.816199  33.021820
# 1  603.992653  14.914810  34.499330
# 2  549.833883  15.964123  35.647232
# 3  564.353878  15.325923  34.974383
# 4  563.354286  15.862481  32.023654

# %%
# Celda 3: Información general del dataframe
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Anio           47 non-null     int64
#  1   Mes            47 non-null     int64
#  2   TempMax        47 non-null     float64
#  3   TempMin        47 non-null     float64
#  4   Precipitacion  47 non-null     float64
#  5   pm10           47 non-null     float64
#  6   pm2_5          47 non-null     float64
#  7   CO             47 non-null     float64
#  8   NO2            47 non-null     float64
#  9   O3             47 non-null     float64
# dtypes: float64(8), int64(2)
# memory usage: 3.8 KB
# Anio             0
# Mes              0
# TempMax          0
# TempMin          0
# Precipitacion    0
# pm10             0
# pm2_5            0
# CO               0
# NO2              0
# O3               0
# dtype: int64

# %%
# Celda 4: Gráficos de barras de variables categóricas (ejemplo: Mes)
plt.figure(figsize=(10,6))
sns.countplot(x="Mes", data=df)
plt.title("Distribución por Mes")
plt.show()

# %%
# Celda 5: Gráfico pastel de proporciones (ejemplo: Mes)
plt.figure(figsize=(6,6))
df['Mes'].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Proporción por Mes")
plt.ylabel("")
plt.show()

# %%
# Celda 6 corregida: Matriz de correlación y gráfico de dispersión
numeric_cols = df.select_dtypes(include="number").columns

# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Celda 8: Histograma de variables numéricas
df[numeric_cols].hist(bins=30, figsize=(12,8))
plt.suptitle("Histogramas de Variables Numéricas", fontsize=16)
plt.show()

# %% [markdown]
# # clima_mensual_2020_2023

# %%
# Celda 2: Cargar los datos
DATA_DIR = os.path.join("..", "data", "processed")  # Ajusta según tu ruta
archivo_clima_cont = "clima_mensual_2020_2023.csv"

df = pd.read_csv(os.path.join(DATA_DIR, archivo_clima_cont))
df.head()
# Out:
#    Anio  Mes    TempMax    TempMin  Precipitacion
# 0  2020    1  25.103226  16.816129       1.374194
# 1  2020    2  26.451724  16.293103       0.227586
# 2  2020    3  27.358065  16.029032       0.251613
# 3  2020    4  27.700000  17.243333       3.066667
# 4  2020    5  25.916129  18.029032      10.641935

# %%
# Celda 3: Información general del dataframe
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Anio           48 non-null     int64
#  1   Mes            48 non-null     int64
#  2   TempMax        48 non-null     float64
#  3   TempMin        48 non-null     float64
#  4   Precipitacion  48 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 2.0 KB
# Anio             0
# Mes              0
# TempMax          0
# TempMin          0
# Precipitacion    0
# dtype: int64

# %%
# Celda 4: Gráficos de barras de variables categóricas (ejemplo: Mes)
plt.figure(figsize=(10,6))
sns.countplot(x="Mes", data=df)
plt.title("Distribución por Mes")
plt.show()

# %%
# Celda 5: Gráfico pastel de proporciones (ejemplo: Mes)
plt.figure(figsize=(6,6))
df['Mes'].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Proporción por Mes")
plt.ylabel("")
plt.show()

# %%
# Celda 6 corregida: Matriz de correlación y gráfico de dispersión
numeric_cols = df.select_dtypes(include="number").columns

# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Celda 8: Histograma de variables numéricas
df[numeric_cols].hist(bins=30, figsize=(12,8))
plt.suptitle("Histogramas de Variables Numéricas", fontsize=16)
plt.show()

# %%
# Celda 2: Cargar los datos
DATA_DIR = os.path.join("..", "data", "processed")  # Ajusta según tu ruta
archivo_clima_cont = "contaminacion_mensual.csv"

df = pd.read_csv(os.path.join(DATA_DIR, archivo_clima_cont))
df.head()
# Out:
#    Anio  Mes       pm10      pm2_5          CO        NO2         O3
# 0  2020    1  14.172637  12.203810  583.596093  14.816199  33.021820
# 1  2020    2  15.015327  13.090243  603.992653  14.914810  34.499330
# 2  2020    3  14.320850  12.337422  549.833883  15.964123  35.647232
# 3  2020    4  14.675192  12.627095  564.353878  15.325923  34.974383
# 4  2020    5  14.182802  12.829312  563.354286  15.862481  32.023654

# %%
# Celda 3: Información general del dataframe
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Anio    47 non-null     int64
#  1   Mes     47 non-null     int64
#  2   pm10    47 non-null     float64
#  3   pm2_5   47 non-null     float64
#  4   CO      47 non-null     float64
#  5   NO2     47 non-null     float64
#  6   O3      47 non-null     float64
# dtypes: float64(5), int64(2)
# memory usage: 2.7 KB
# Anio     0
# Mes      0
# pm10     0
# pm2_5    0
# CO       0
# NO2      0
# O3       0
# dtype: int64

# %%
# Celda 4: Gráficos de barras de variables categóricas (ejemplo: Mes)
plt.figure(figsize=(10,6))
sns.countplot(x="Mes", data=df)
plt.title("Distribución por Mes")
plt.show()

# %%
# Celda 5: Gráfico pastel de proporciones (ejemplo: Mes)
plt.figure(figsize=(6,6))
df['Mes'].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Proporción por Mes")
plt.ylabel("")
plt.show()

# %%
# Celda 6 corregida: Matriz de correlación y gráfico de dispersión
numeric_cols = df.select_dtypes(include="number").columns

# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Celda 8: Histograma de variables numéricas
df[numeric_cols].hist(bins=30, figsize=(12,8))
plt.suptitle("Histogramas de Variables Numéricas", fontsize=16)
plt.show()

# %%
# Celda 2: Cargar los datos
DATA_DIR = os.path.join("..", "data", "processed")  # Ajusta según tu ruta
archivo_clima_cont = "peajes_clean.csv"

df = pd.read_csv(os.path.join(DATA_DIR, archivo_clima_cont))
df.head()
# Out:
#     Año      Mes Puesto de Peaje   Liviano  Dos Tres Ejes   Furgón  \
# 0  2024    Junio          Zurquí  115833.0        17658.0  27383.0
# 1  2024     Mayo          Zurquí  123850.0        19044.0  28348.0
# 2  2024    Abril          Zurquí  123439.0        18211.0  27053.0
# 3  2024    Marzo          Zurquí  142170.0        18470.0  26555.0
# 4  2024  Febrero          Zurquí   92252.0        14624.0  23341.0
#
#    Motocicletas  Autobus     Total
# 0        7826.0   7140.0  175840.0
# 1        8500.0   7332.0  187074.0
# 2        8427.0   7799.0  184929.0
# 3        9255.0   9870.0  206320.0
# 4        6082.0   6675.0  142974.0

# %%
# Celda 3: Información general del dataframe
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Año              618 non-null    int64
#  1   Mes              618 non-null    object
#  2   Puesto de Peaje  618 non-null    object
#  3   Liviano          618 non-null    float64
#  4   Dos Tres Ejes    618 non-null    float64
#  5   Furgón           618 non-null    float64
#  6   Motocicletas     618 non-null    float64
#  7   Autobus          618 non-null    float64
#  8   Total            618 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 43.6+ KB
# Año                0
# Mes                0
# Puesto de Peaje    0
# Liviano            0
# Dos Tres Ejes      0
# Furgón             0
# Motocicletas       0
# Autobus            0
# Total              0
# dtype: int64

# %%
# Celda 4: Gráficos de barras de variables categóricas (ejemplo: Mes)
plt.figure(figsize=(10,6))
sns.countplot(x="Mes", data=df)
plt.title("Distribución por Mes")
plt.show()

# %%
# Celda 5: Gráfico pastel de proporciones (ejemplo: Mes)
plt.figure(figsize=(6,6))
df['Mes'].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Proporción por Mes")
plt.ylabel("")
plt.show()

# %%
# Celda 6 corregida: Matriz de correlación y gráfico de dispersión
numeric_cols = df.select_dtypes(include="number").columns

# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# %%
# Celda 8: Histograma de variables numéricas
df[numeric_cols].hist(bins=30, figsize=(12,8))
plt.suptitle("Histogramas de Variables Numéricas", fontsize=16)
plt.show()
